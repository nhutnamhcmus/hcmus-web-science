# %% [markdown]
# # Lab02: Web Crawler (Continue).
#
# - MSSV: 18120061
# - Họ và tên: Lê Nhựt Nam

# %% [markdown]
# ## Yêu cầu bài tập
#
# **Cách làm bài**
#
#
# Bạn sẽ làm trực tiếp trên file notebook này; trong file, từ `TODO` để cho biết những phần mà bạn cần phải làm.
#
# Bạn có thể thảo luận ý tưởng cũng như tham khảo các tài liệu, nhưng *code và bài làm phải là của bạn*.
#
# Nếu vi phạm thì sẽ bị 0 điểm cho bài tập này.
#
# **Cách nộp bài**
#
# Trước khi nộp bài, rerun lại notebook (`Kernel` -> `Restart & Run All`).
#
# Bạn nộp file notebook với tên `MSSV.ipynb` của bạn (vd, nếu bạn có MSSV là 1234567 thì bạn đặt tên file là `1234567.ipynb`) và nộp file này trên moodle.
#
# **Nội dung bài tập**
#
# Thu thập và thể hiện dữ liệu web.

# %% [markdown]
# ## 2. Cài đặt

# %% [markdown]
# ### 2.1. Import library

# %%
#!pip install beautifulsoup4
# If you use Anaconda env or Minianconda
#!conda install -c anaconda beautifulsoup4

import requests
import re
from bs4 import BeautifulSoup
from bs4.element import Comment
import string

# %% [markdown]
# ### 2.2. HTML Parser

# %% [markdown]
# Bộ phân tích cú pháp HTML (HTML Parser): nhận HTML code và trích xuất thông tin liên quan như tiêu đề của trang, đoạn văn trong trang, tiêu đề trong trang, liên kết, văn bản in đậm, v.v.

# %%
from html.parser import HTMLParser

class MyHTMLParser(HTMLParser):
    def handle_starttag(self, tag, attrs):
        print("Start tag:", tag)

    def handle_endtag(self, tag):
        print("End tag :", tag)

    def handle_data(self, data):
        print("Data  :", data)

parser = MyHTMLParser()
parser.feed('<html><head><title>Test</title></head>')
# Out:
# Start tag: html
# Start tag: head
# Start tag: title
# Data  : Test
# End tag : title
# End tag : head

# %% [markdown]
# #### Loại bỏ các HTML tag không cần thiết bằng cách thiết lập filter

# %%
def text_filter(element):
    if element.parent.name in ['style', 'title', 'script', 'head', '[document]', 'class', 'a', 'li']:
        return False
    elif isinstance(element, Comment):
        '''Opinion mining?'''
        return False
    elif re.match(r"[\s\r\n]+",str(element)): 
        '''space, return, endline'''
        return False
    return True

# %% [markdown]
# ### 2.3 Thu thập nội dung trang Web

# %% [markdown]
# #### Trong bài tập này ta thể hiện tài liệu (hay nội dung trang web) với cấu trúc đơn giản như sau:
# - Gọi $D$ là một tập tài liệu chứa *n* tài liệu: $D=\left\{d_1,d_2,...,d_n\right\}$.
# - Ta thể hiện tài liệu bằng một dictionary `data={}` với `data[word]=[[url_idx_1,url_idx_2,...],frequency]` với `url_index`$\in{\left[{1,n}\right]}$
#
# VD: `data['at']=[[1,2], 5]`
# Từ `at` xuất hiện trong đường dẫn có index `1` và `2` tổng số lần xuất hiện là 5.

# %% [markdown]
# #### Bước 1: liệt kê các từ xuất hiện trong trang web:

# %%
def wordList(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.content, "html.parser")
    text = soup.findAll(text=True)
    filtered_text = list(filter(text_filter, text)) # list của các chuỗi
    word_list = []
    # TODO:
    # Với mỗi chuỗi trong filtered_text:
    for text in filtered_text:
        #   Thay thế các dấu câu thành khoảng trắng (gợi ý: danh sách các dấu câu: string.punctuation; thay thế: .replace(...))
        #   Sử dụng .join() function, nếu một char c nào đó nằm trong string.punctuation thì nó sẽ được thay thế bằng ' '. Ngược lại thì không thay đổi gì
        # sau đó join với một string rỗng để có được clean_text
        clean_text = ''.join(' ' if c in string.punctuation else c for c in text)
        #   Tách chuỗi bởi khoảng trắng (.split(...))
        # cắt clean_text vừa có ở trên ra
        lst_words_in_clean_text = clean_text.split()
        #   Thêm các từ vừa được tách ra vào word_list
        word_list = word_list + lst_words_in_clean_text
    return word_list
  
# Test
print(wordList('https://en.wikipedia.org/wiki/Web_mining'))
# Out:
# ['Web', 'mining', 'From', 'Wikipedia', 'the', 'free', 'encyclopedia', 'This', 'article', 'includes', 'a', 'related', 'reading', 'or', 'but', 'its', 'sources', 'remain', 'unclear', 'because', 'it', 'lacks', 'October', '2020', 'This', 'article', 'may', 'require', 'The', 'specific', 'problem', 'is', 'The', 'article', 'needs', 'sufficient', 'inline', 'references', 'and', 'a', 'complete', 're', 'write', 'has', 'been', 'proposed', 'October', '2020', 'Web', 'mining', 'It', 'uses', 'automated', 'methods', 'to', 'extract', 'both', 'structured', 'and', 'unstructured', 'data', 'from', 'web', 'pages', 'server', 'logs', 'and', 'link', 'structures', 'There', 'are', 'three', 'main', 'sub', 'categories', 'of', 'web', 'mining', 'Contents', '1', 'Web', 'mining', 'types', '2', 'Web', 'usage', 'mining', '2', '1', 'Pros', '2', '2', 'Cons', '3', 'Web', 'structure', 'mining', '4', 'Web', 'content', 'mining', '4', '1', 'Web', 'content', 'mining', 'in', 'foreign', 'languages', '4', '1', '1', 'Chinese', '5', 'See', 'also', '6', 'References', '6', '1', 'Books', '6', '2', 'Bibliographic', 'references', 'Web', 'mining', 'types', 'Web', 'mining', 'can', 'be', 'divided', 'into', 'three', 'different', 'types', '–', 'Web', 'usage', 'mining', 'Web', 'content', 'mining', 'Web', 'structure', 'mining', 'The', 'general', 'relationship', 'between', 'the', 'categories', 'of', 'Web', 'mining', 'and', 'objectives', 'of', 'data', 'mining', 'Comparison', 'Web', 'content', 'mining', 'Web', 'structure', 'mining', 'Web', 'usage', 'mining', 'IR', 'view', 'DB', 'view', 'View', 'of', 'data', 'Main', 'data', 'Representation', 'Method', 'Application', 'categories', 'Web', 'usage', 'mining', 'Web', 'usage', 'mining', 'is', 'the', 'application', 'of', 'Usage', 'data', 'captures', 'the', 'identity', 'or', 'origin', 'of', 'Web', 'users', 'along', 'with', 'their', 'browsing', 'behavior', 'at', 'a', 'Web', 'site', 'Web', 'usage', 'mining', 'itself', 'can', 'be', 'classified', 'further', 'depending', 'on', 'the', 'kind', 'of', 'usage', 'data', 'considered', 'Web', 'server', 'data', 'Application', 'server', 'data', 'Application', 'level', 'data', 'Studies', 'related', 'to', 'work', 'Pros', 'Web', 'usage', 'mining', 'essentially', 'has', 'many', 'advantages', 'which', 'makes', 'this', 'technology', 'attractive', 'to', 'corporations', 'including', 'government', 'agencies', 'This', 'technology', 'has', 'enabled', 'which', 'eventually', 'results', 'in', 'higher', 'trade', 'volumes', 'Government', 'agencies', 'are', 'using', 'this', 'technology', 'to', 'classify', 'threats', 'and', 'The', 'predicting', 'capability', 'of', 'mining', 'applications', 'can', 'benefit', 'society', 'by', 'identifying', 'criminal', 'activities', 'Companies', 'can', 'establish', 'better', 'More', 'benefits', 'of', 'web', 'usage', 'mining', 'particularly', 'in', 'the', 'area', 'of', 'are', 'outlined', 'in', 'specific', 'frameworks', 'such', 'as', 'the', 'Cons', 'Web', 'usage', 'mining', 'by', 'itself', 'does', 'not', 'create', 'issues', 'but', 'this', 'technology', 'when', 'used', 'on', 'Privacy', 'is', 'considered', 'lost', 'when', 'information', 'concerning', 'an', 'individual', 'is', 'obtained', 'used', 'or', 'disseminated', 'especially', 'if', 'this', 'occurs', 'without', 'the', 'individual', 's', 'knowledge', 'or', 'consent', 'then', 'Another', 'important', 'concern', 'is', 'that', 'the', 'companies', 'collecting', 'the', 'data', 'for', 'a', 'specific', 'purpose', 'might', 'use', 'the', 'data', 'for', 'totally', 'different', 'purposes', 'and', 'this', 'essentially', 'violates', 'the', 'user', 's', 'interests', 'The', 'growing', 'trend', 'of', 'selling', 'personal', 'data', 'as', 'a', 'commodity', 'encourages', 'website', 'owners', 'to', 'trade', 'personal', 'data', 'obtained', 'from', 'their', 'site', 'This', 'trend', 'has', 'increased', 'the', 'amount', 'of', 'data', 'being', 'captured', 'and', 'traded', 'increasing', 'the', 'likeliness', 'of', 'one', 's', 'privacy', 'being', 'invaded', 'The', 'companies', 'wh ...

# %% [markdown]
# #### Bước 2: Tính tần suất xuất hiện của từ trong 1 trang web, lưu trữ dữ liệu vào data:

# %%
def read_url(url, url_idx, data):
    word_list = wordList(url)
    # TODO
    # Với mỗi từ w trong word_list:
    for i, word in enumerate(word_list):
        #   Nếu w chưa có trong data thì khởi tạo data[w] = [[url_idx], 1]
        if word not in data.keys():
            data[word]=[[url_idx],1]
        #   Ngược lại thì thêm url_idx vào data[w][0] (nếu chưa có) và tăng data[w][1] lên 1 đơn vị
        else:
            if url_idx in data[word][0]:
                data[word][0].append(i)
            data[word][1]+=1

# Test
test_data = {}
read_url('https://en.wikipedia.org/wiki/Web_mining', 1, test_data)
test_data
# Out:
# {'Web': [[1,
#    48,
#    80,
#    84,
#    94,
#    98,
#    103,
#    125,
#    128,
#    138,
#    141,
#    144,
#    154,
#    162,
#    165,
#    168,
#    184,
#    187,
#    202,
#    211,
#    213,
#    229,
#    243,
#    318,
#    512,
#    533,
#    537,
#    552,
#    555,
#    571,
#    631,
#    693,
#    710,
#    766,
#    787,
#    793,
#    810,
#    836,
#    878,
#    895],
#   40],
#  'mining': [[1,
#    49,
#    77,
#    81,
#    86,
#    96,
#    100,
#    105,
#    126,
#    129,
#    140,
#    143,
#    146,
#    155,
#    160,
#    164,
#    167,
#    170,
#    186,
#    189,
#    215,
#    245,
#    285,
#    303,
#    320,
#    453,
#    487,
#    514,
#    535,
#    539,
#    549,
#    554,
#    557,
#    560,
#    621,
#    633,
#    694,
#    712,
#    739],
#   39],
#  'From': [[1], 1],
#  'Wikipedia': [[1, 963], 2],
#  'the': [[1,
#    151,
#    191,
#    197,
#    223,
#    306,
#    316,
#    352,
#    364,
#    367,
#    375,
#    385,
#    414,
#    423,
#    435,
#    460,
#    463,
#    468,
#    484,
#    508,
#    551,
#    559,
#    577,
#    652,
#    660,
#    663,
#    669,
#    687,
#    697,
#    703,
#    722,
#    726,
#    918],
#   33],
#  'free': [[1], 1],
#  'encyclopedia': [[1], 1],
#  'This': [[1, 24, 260, 410, 515, 525], 6],
#  'article': [[1, 25, 33, 961], 4],
#  'includes': [[1], 1],
#  'a': [[1, 39, 210, 370, 397, 544, 625, 823], 8],
#  'related': [[1, 239], 2],
#  'reading': [[1], 1],
#  'or': [[1, 199, 345, 356, 497, 596], 6],
#  'but': [[1, 327, 475, 585], 4],
#  'its': [[1], 1],
#  'sources': [[1], 1],
#  'remain': [[1], 1],
#  'unclear': [[1], 1],
#  'because': [[1], 1],
#  'it': [[1, 440, 731], 3],
#  'lacks': [[1], 1],
#  'October': [[1, 46, 531], 3],
#  '2020': [[1, 47, 532], 3],
#  'may': [[1], 1],
#  'require': [[1], 1],
#  'The': [[1, 32, 147, 281, 389, 431, 574, 676, 717], 9],
#  'specific': [[1, 312, 371, 450], 4],
#  'problem': [[1], 1],
#  'is': [[1, 190, 334, 342, 362, 477, 527, 550, 558, 634, 666, 674, 679, 702],
#   14],
#  'needs': [[1, 517, 719], 3],
#  'sufficient': [[1], 1],
#  'inline': [[1], 1],
#  'references': [[1, 124, 925], 3],
#  'and': [[1,
#    58,
#    66,
#    156,
#    280,
#    381,
#    420,
#    442,
#    562,
#    568,
#    576,
#    578,
#    619,
#    692,
#    729,
#    745,
#    786,
#    813,
#    853],
#   19],
#  'complete': [[1], 1],
#  're': [[1], 1],
#  'write': [[1], 1],
#  'has': [[1, 247, 262, 412], 4],
#  'been': [[1], 1],
#  'proposed': [[1], 1],
#  'It': [[1], 1],
#  'uses': [[1, 536], 2],
#  'automated': [[1], 1],
#  'methods': [[1], 1],
#  'to': [[1,
#    240,
#    255,
#    277,
#    402,
#    500,
#    583,
#    604,
#    616,
#    623,
#    646,
#    680,
#    685,
#    720,
#    741,
#    970],
#   16],
#  'extract': [[1], 1],
#  'both': [[1], 1],
#  'structured': [[1], 1],
#  'unstructured': [[1], 1],
#  'data': [[1,
#    159,
#    177,
#    179,
#    195,
#    227,
#    231,
#    234,
#    237,
#    368,
#    376,
#    395,
#    405,
#    417,
#    436,
#    485,
#    566,
#    620,
#    738],
#   19],
#  'from': [[1, 407, 482, 570, 636, 707, 927], 7],
#  'web': [[1, 76, 301, 547], 4],
#  'pages': [[1, 987], 2],
#  'server': [[1, 230, 233], 3],
#  'logs': [[1], 1],
#  'link': [[1, 989], 2],
#  'structures': [[1], 1],
#  'There': [[1, 642], 2],
#  'are': [[1, 273, 309, 437, 445, 456, 643], 7],
#  'three': [[1, 134], 2],
#  'main': [[1], 1],
#  'sub': [[1], 1],
#  'categories': [[1, 152, 183, 929], 4],
#  'of': [[1,
#    153,
#    158,
#    176,
#    193,
#    201,
#    225,
#    284,
#    300,
#    308,
#    392,
#    416,
#    425,
#    448,
#    452,
#    462,
#    543,
#    546,
#    564,
#    628,
#    640,
#    671,
#    699,
#    705,
#    725,
#    856,
#    917],
#   27],
#  'Contents': [[1, 957], 2],
#  '1': [[1, 88, 102, 110, 111, 119, 883], 7],
#  'types': [[1, 127, 136], 3],
#  '2': [[1, 87, 90, 91, 122, 902], 6],
#  'usage': [[1, 139, 169, 185, 188, 214, 226, 244, 302, 319], 10],
#  'Pros': [[1, 242], 2],
#  'Cons': [[1, 317], 2],
#  '3': [[1], 1],
#  'structure': [[1, 145, 166, 513, 534, 538, 548], 7],
#  '4': [[1, 101, 109, 798], 4],
#  'content': [[1, 104, 142, 163, 553, 556, 573, 632, 711], 9],
#  'in': [[1, 267, 305, 311, 467, 472, 528, 713, 835, 859, 936, 942], 12],
#  'foreign': [[1, 714], 2],
#  'languages': [[1, 715], 2],
#  'Chinese': [[1, 716], 2],
#  '5': [[1], 1],
#  'See': [[1, 748], 2],
#  'also': [[1, 749], 2],
#  '6': [[1, 118, 121, 799, 886], 5],
#  'References': [[1, 750], 2],
#  'Books': [[1, 923], 2],
#  'Bibliographic': [[1, 924], 2],
#  'can': [[1, 217, 287, 295, 520, 655, 695], 7],
#  'be': [[1, 218, 506], 3],
#  'divided': [[1], 1],
#  'into': [[1, 732], 2],
#  'different': [[1, 379, 638], 3],
#  '–': [[1, 770], 2],
#  'general': [[1, 677], 2],
#  'relationship': [[1], 1],
#  'between': [[1], 1],
#  'objectives': [[1], 1],
#  'Comparison': [[1], 1],
#  'IR': [[1], 1],
#  'view': [[1, 174, 641], 3],
#  'DB': [[1], 1],
#  'View': [[1, 950], 2],
#  'Main': [[1, 955], 2],
#  'Representation': [[1], 1],
#  'Method': [[1], 1],
#  'Application': [[1, 232, 235], 3],
#  'application': [[1], 1],
#  'Usage': [[1], 1],
#  'captures': [[1], 1],
#  'identity': [[1], 1],
#  'origin': [[1], 1],
#  'users': [[1, 584], 2],
#  'along': [[1], 1],
#  'with': [[1], 1],
#  'their': [[1, 408], 2],
#  'browsing': [[1], 1],
#  'behavior': [[1], 1],
#  'at': [[1], 1],
#  'site': [[1, 409], 2],
#  'itself': [[1, 322], 2],
#  'classified': [[1], 1],
#  'further': [[1], 1],
#  'depending': [[1], 1],
#  'on': [[1, 332, 877], 3],
#  'kind': [[1], 1],
#  'considered': [[1, 335, 446], 3],
#  'level': [[1, 627], 2],
#  'Studies': [[1], 1],
#  'work': [[1], 1],
#  'essentially': [[1, 383], 2],
#  'many': [[1], 1],
#  'advantages': [[1], 1],
#  'which': [[1, 264, 433], 3],
#  'makes': [[1], 1],
#  'this': [[1, 275, 328, 349, 382, 993], 6],
#  'technology': [[1, 261, 276, 329], 4],
#  'attractive': [[1], 1],
#  'corporations': [[1], 1],
#  'including': [[1], 1],
#  'government': [[1], 1],
#  'agencies': [[1, 272], 2],
#  'enabled': [[1], 1],
#  'eventually': [[1], 1],
#  'results': [[1], 1],
#  'higher': [[1, 626], 2],
#  'trade': [[1, 403], 2],
#  'volumes': [[1], 1],
#  'Government': [[1], 1],
#  'using': [[1], 1],
#  'classify': [[1], 1],
#  'threats': [[1], 1],
#  'predicting': [[1], 1],
#  'capability': [[1], 1],
#  'applications': [[1], 1],
#  'benefit': [[1], 1],
#  'society': [[1], 1],
#  'by': [[1, 321, 522], 3],
#  'identifying': [[1], 1],
#  'criminal': [[1], 1],
#  'activities': [[1], 1],
#  'Companies': [[1], 1],
#  'establish': [[1], 1],
#  'better': [[1], 1],
#  'More': [[1, 952], 2],
#  'benefits': [[1], 1],
#  'particularly': [[1], 1],
#  'area': [[1], 1],
#  'outlined': [[1], 1],
#  'frameworks': [[1], 1],
#  'such': [[1, 610], 2],
#  'as': [[1, 396, 611, 613, 615, 1000], 6],
#  'does': [[1], 1],
#  'not': [[1, 588], 2],
#  'create': [[1], 1],
#  'issues': [[1], 1],
#  'when': [[1, 337], 2],
#  'used': [[1, 344], 2],
#  'Privacy': [[1, 857], 2],
#  'lost': [[1], 1],
#  'information': [[1, 567, 592, 991], 4],
#  'concerning': [[1], 1],
#  'an': [[1, 682, 700], 3],
#  'individual': [[1, 353], 2],
#  'obtained': [[1, 406], 2],
#  'disseminated': [[1], 1],
#  'especially': [[1], 1],
#  'if': [[1, 529], 2],
#  'occurs': [[1], 1],
#  'without': [[1], 1],
#  's': [[1, 387, 427], 3],
#  'knowledge': [[1, 569, 744], 3],
#  'consent': [[1], 1],
#  'then': [[1, 735], 2],
#  'Another': [[1], 1],
#  'important': [[1], 1],
#  'concern': [[1], 1],
#  'that': [[1, 662], 2],
#  'companies': [[1, 432, 444], 3],
#  'collecting': [[1], 1],
#  'for': [[1, 377, 459, 609, 630], 5],
#  'purpose': [[1], 1],
#  'might': [[1, 489, 505], 3],
#  'use': [[1, 490, 736], 3],
#  'totally': [[1], 1],
#  'purposes': [[1], 1],
#  'violates': [[1], 1],
#  'user': [[1], 1],
#  'interests': [[1], 1],
#  'growing': [[1], 1],
#  'trend': [[1, 411], 2],
#  'selling': [[1], 1],
#  'personal': [[1, 404], 2],
#  'commodity': [[1], 1],
#  'encourages': [[1], 1],
#  'website': [[1], 1],
#  'owners': [[1], 1],
#  'increased': [[1], 1],
#  'amount': [[1], 1],
#  'being': [[1, 429], 2],
#  'captured': [[1], 1],
#  'traded': [[1], 1],
#  'increasing': [[1], 1],
#  'likeliness': [[1], 1],
#  'one': [[1, 718], 2],
#  'privacy': [[1], 1],
#  'invaded': [[1], 1],
#  'buy': [[1], 1],
#  'obliged': [[1], 1],
#  'make': [[1], 1],
#  'anonymous': [[1], 1],
#  'these': [[1], 1],
#  'authors': [[1], 1],
#  'any': [[1, 465], 2],
#  'release': [[1, 464, 469], 3],
#  'patterns': [[1, 747], 2],
#  'They': [[1], 1],
#  'legally': [[1], 1],
#  'responsible': [[1], 1],
#  'contents': [[1], 1],
#  'inaccuracies': [[1], 1],
#  'will': [[1], 1],
#  'result': [[1, 665], 2],
#  'serious': [[1], 1],
#  'lawsuits': [[1], 1],
#  'there': [[1], 1],
#  'no': [[1], 1],
#  'law': [[1], 1],
#  'preventing': [[1], 1],
#  'them': [[1], 1],
#  'trading': [[1], 1],
#  'Some': [[1], 1],
#  'algorithms': [[1], 1],
#  'controversial': [[1], 1],
#  'attributes': [[1], 1],
#  'like': [[1], 1],
#  'sex': [[1], 1],
#  'race': [[1], 1],
#  'religion': [[1], 1],
#  'sexual': [[1], 1],
#  'orientation': [[1], 1],
#  'categorize': [[1, 594], 2],
#  'individuals': [[1], 1],
#  'These': [[1, 599], 2],
#  'practices': [[1], 1],
#  'against': [[1], 1],
#  'anti': [[1], 1],
#  'discrimination': [[1], 1],
#  'legislation': [[1], 1],
#  'section': [[1, 526], 2],
#  'expansion': [[1], 1],
#  'You': [[1], 1],
#  'help': [[1], 1],
#  'June': [[1], 1],
#  '2015': [[1], 1],
#  'appropriate': [[1], 1],
#  'terminology': [[1], 1],
#  'An': [[1], 1],
#  'example': [[1, 701], 2],
#  'techniques': [[1, 622, 740], 3],
#  'extraction': [[1, 670], 2],
#  'integration': [[1], 1],
#  'useful': [[1, 743, 746], 3],
#  'page': [[1, 956, 994], 3],
#  'heterogeneity': [[1], 1],
#  'others': [[1], 1],
#  'provide': [[1, 590, 624], 3],
#  'some': [[1], 1],
#  'comfort': [[1], 1],
#  'they': [[1], 1],
#  'do': [[1], 1],
#  'generally': [[1], 1],
#  'structural': [[1], 1],
#  'nor': [[1], 1],
#  'filter': [[1], 1],
#  'interpret': [[1], 1],
#  'documents': [[1, 648, 728], 3],
#  'factors': [[1], 1],
#  'have': [[1], 1],
#  'prompted': [[1], 1],
#  'researchers': [[1], 1],
#  'develop': [[1], 1],
#  'more': [[1], 1],
#  'intelligent': [[1, 612], 2],
#  'tools': [[1, 933], 2],
#  'well': [[1], 1],
#  'extend': [[1], 1],
#  'database': [[1], 1],
#  'organization': [[1], 1],
#  'differentiated': [[1], 1],
#  'two': [[1], 1],
#  'points': [[1], 1],
#  'several': [[1], 1],
#  'ways': [[1], 1],
#  'represent': [[1], 1],
#  'By': [[1], 1],
#  'multi': [[1], 1],
#  'scanning': [[1], 1],
#  'document': [[1], 1],
#  'we': [[1], 1],
#  'implement': [[1], 1],
#  'feature': [[1, 672, 690], 3],
#  'selection': [[1], 1],
#  'Under': [[1], 1],
#  'condition': [[1], 1],
#  'category': [[1], 1],
#  'rarely': [[1], 1],
#  'affected': [[1], 1],
#  'subset': [[1], 1],
#  'needed': [[1], 1],
#  'algorithm': [[1], 1],
#  'construct': [[1], 1],
#  'evaluating': [[1], 1],
#  'function': [[1], 1],
#  'evaluate': [[1], 1],
#  'features': [[1], 1],
#  'As': [[1], 1],
#  'set': [[1], 1],
#  'complement': [[1], 1],
#  'retrieval': [[1], 1],
#  'aggregation': [[1], 1],
#  'works': [[1], 1],
#  'academic': [[1], 1],
#  'publications': [[1], 1],
#  'identify': [[1], 1],
#  'code': [[1, 734], 2],
#  'standard': [[1], 1],
#  'HTML': [[1], 1],
#  'transform': [[1], 1],
#  'inner': [[1], 1],
#  'other': [[1], 1],
#  'find': [[1], 1],
#  'Weichbroth': [[1], 1],
#  'et': [[1], 1],
#  'al': [[1], 1],
#  'Ngu': [[1], 1],
#  'Anne': [[1], 1],
#  'Kitsuregawa': [[1], 1],
#  'Masaru': [[1], 1],
#  'Chung': [[1], 1],
#  'Jen': [[1], 1],
#  'Yao': [[1], 1],
#  'Neuhold': [[1], 1],
#  'Erich': [[1], 1],
#  'Sheng': [[1], 1],
#  'Quan': [[1], 1],
#  '2005': [[1, 772, 809], 3],
#  'Information': [[1], 1],
#  'Systems': [[1], 1],
#  'Engineering': [[1], 1],
#  'WISE': [[1], 1],
#  'Berlin': [[1, 802], 2],
#  'Springer': [[1, 803], 2],
#  'pp': [[1, 804, 820], 3],
#  '9783540300175': [[1], 1],
#  'Bauknecht': [[1], 1],
#  'Kurt': [[1], 1],
#  'Madria': [[1], 1],
#  'Sanjay': [[1], 1],
#  'Pernul': [[1], 1],
#  'Gunther': [[1], 1],
#  '2000': [[1, 794, 800, 894], 4],
#  'Electronic': [[1], 1],
#  'Commerce': [[1], 1],
#  'Technologies': [[1], 1],
#  'First': [[1], 1],
#  'International': [[1, 875], 2],
#  'Conference': [[1, 876], 2],
#  'EC': [[1], 1],
#  'London': [[1], 1],
#  'UK': [[1], 1],
#  'September': [[1], 1],
#  'Proceedings': [[1], 1],
#  '978': [[1, 821, 882], 3],
#  '3540679813': [[1], 1],
#  'Scime': [[1], 1],
#  'Anthony': [[1], 1],
#  'Mining': [[1, 838, 861, 896], 4],
#  'Applications': [[1], 1],
#  'Techniques': [[1], 1],
#  'Hershey': [[1], 1],
#  'PA': [[1], 1],
#  'Idea': [[1], 1],
#  'Group': [[1], 1],
#  'Publishing': [[1], 1],
#  '1591404149': [[1], 1],
#  'b': [[1], 1],
#  'c': [[1], 1],
#  'Lita': [[1], 1],
#  'van': [[1], 1],
#  'Wel': [[1], 1],
#  'Lambèr': [[1], 1],
#  'Royakkers': [[1], 1],
#  '2004': [[1], 1],
#  'PDF': [[1, 851, 1001], 3],
#  'Ethical': [[1], 1],
#  'Issues': [[1, 855], 2],
#  'Data': [[1, 860], 2],
#  'Kirsten': [[1], 1],
#  'Maelstrom': [[1], 1],
#  'John': [[1], 1],
#  'F': [[1], 1],
#  'Rodrick': [[1], 1],
#  'Vladimir': [[1], 1],
#  'Estivill': [[1], 1],
#  'Castro': [[1], 1],
#  'Denise': [[1], 1],
#  'de': [[1], 1],
#  'Vries': [[1], 1],
#  '2007': [[1], 1],
#  'Legal': [[1], 1],
#  'Technical': [[1], 1],
#  'Preservation': [[1], 1],
#  'Annamoradnejad': [[1, 864], 2],
#  'R': [[1], 1],
#  'I': [[1], 1],
#  'Safarrad': [[1], 1],
#  'T': [[1], 1],
#  'Habibi': [[1], 1],
#  'J': [[1], 1],
#  '2019': [[1, 873, 915], 3],
#  '04': [[1], 1],
#  '20': [[1], 1],
#  '5th': [[1], 1],
#  'Research': [[1, 897], 2],
#  'ICWR': [[1], 1],
#  '55–60': [[1], 1],
#  '7281': [[1], 1],
#  '1431': [[1], 1],
#  'Wang': [[1], 1],
#  'Yan': [[1], 1],
#  'Kosala': [[1], 1],
#  'Raymond': [[1], 1],
#  'Hendrik': [[1], 1],
#  'Blockeel': [[1], 1],
#  'July': [[1], 1],
#  'A': [[1, 905], 2],
#  'Survey': [[1], 1],
#  'SIGKDD': [[1], 1],
#  'Explorations': [[1], 1],
#  'Speirs': [[1], 1],
#  'Martha': [[1], 1],
#  '2013': [[1], 1],
#  'Cite': [[1, 992], 2],
#  'journal': [[1, 910], 2],
#  'requires': [[1], 1],
#  'Dhakal': [[1], 1],
#  'Kerry': [[1], 1],
#  '15': [[1], 1],
#  'April': [[1], 1],
#  'Journal': [[1], 1],
#  'Medical': [[1], 1],
#  'Library': [[1], 1],
#  'Association': [[1], 1],
#  '107': [[1], 1],
#  'Retrieved': [[1], 1],
#  'Hidden': [[1], 1],
#  'Navigation': [[1, 954], 2],
#  'menu': [[1], 1],
#  'Personal': [[1], 1],
#  'Not': [[1], 1],
#  'logged': [[1], 1],
#  'Talk': [[1, 945], 2],
#  'Contributions': [[1], 1],
#  'Create': [[1], 1],
#  'account': [[1], 1],
#  'Log': [[1], 1],
#  'Namespaces': [[1], 1],
#  'Article': [[1], 1],
#  'English': [[1], 1],
#  'Views': [[1], 1],
#  'Read': [[1], 1],
#  'Edit': [[1], 1],
#  'history': [[1], 1],
#  'Search': [[1], 1],
#  'Current': [[1], 1],
#  'events': [[1], 1],
#  'Random': [[1], 1],
#  'About': [[1], 1],
#  'Contact': [[1], 1],
#  'us': [[1], 1],
#  'Donate': [[1], 1],
#  'Contribute': [[1], 1],
#  'Help': [[1], 1],
#  'Learn': [[1], 1],
#  'edit': [[1], 1],
#  'Community': [[1], 1],
#  'portal': [[1], 1],
#  'Recent': [[1], 1],
#  'changes': [[1, 983], 2],
#  'Upload': [[1, 984], 2],
#  'file': [[1, 985], 2],
#  'Tools': [[1], 1],
#  'What': [[1], 1],
#  'links': [[1], 1],
#  'here': [[1], 1],
#  'Related': [[1], 1],
#  'Special': [[1], 1],
#  'Permanent': [[1], 1],
#  'Page': [[1], 1],
#  'Wikidata': [[1], 1],
#  'item': [[1], 1],
#  'Print': [[1], 1],
#  'export': [[1], 1],
#  'Download': [[1], 1],
#  'Printable': [[1], 1],
#  'version': [[1], 1],
#  'Languages': [[1], 1],
#  'العربية': [[1], 1],
#  'Deutsch': [[1], 1],
#  'Español': [[1], 1],
#  'Euskara': [[1], 1],
#  'فارسی': [[1], 1],
#  'Français': [[1], 1],
#  '한국어': [[1], 1],
#  'हिन्दी': [[1], 1],
#  'Hrvatski': [[1], 1],
#  'Magyar': [[1], 1],
#  '日本語': [[1], 1],
#  'Português': [[1], 1],
#  'Русский': [[1], 1],
#  'Slovenčina': [[1], 1],
#  'ไทย': [[1], 1]}

# %% [markdown]
# #### Bước 3: Chạy chương trình lưu kết quả vào file output.txt

# %%
data = {}
read_url('https://en.wikipedia.org/wiki/Web_mining', 1, data)
read_url('https://en.wikipedia.org/wiki/Data_mining', 2, data)

sorted_keys = sorted(data.keys())

with open("output.txt", "w", encoding="utf-8") as f:
    output_line = "Word".ljust(20) + "Frequency".ljust(15) + "URL_idx".ljust(15) + "\n"
    f.writelines(output_line)
    f.writelines('---------------------------------------------------------------------\n\n')
    for key in sorted_keys:
        output_string = str(key).ljust(20) + str(data[key][1]).ljust(15) + str(data[key][0]).ljust(15) + "\n"
        f.writelines(output_string)

# %%
# TODO
# Keyword tìm kiếm: python pickle
# Dùng pickle để lưu dictionary data xuống đĩa. Sau đó đọc lên và in ra 10 giá trị đầu tiên của nó.

# 1. Lưu data
import pickle
out = open("output.pickle", "wb")
pickle.dump(data, out)

# 2. Đọc lên và in ra
output = {}
with open("output.pickle", "rb") as f:
    output = pickle.load(f)

from itertools import islice
list(islice(output.items(), 10))
# Out:
# [('Web',
#   [[1,
#     48,
#     80,
#     84,
#     94,
#     98,
#     103,
#     125,
#     128,
#     138,
#     141,
#     144,
#     154,
#     162,
#     165,
#     168,
#     184,
#     187,
#     202,
#     211,
#     213,
#     229,
#     243,
#     318,
#     512,
#     533,
#     537,
#     552,
#     555,
#     571,
#     631,
#     693,
#     710,
#     766,
#     787,
#     793,
#     810,
#     836,
#     878,
#     895],
#    41]),
#  ('mining',
#   [[1,
#     49,
#     77,
#     81,
#     86,
#     96,
#     100,
#     105,
#     126,
#     129,
#     140,
#     143,
#     146,
#     155,
#     160,
#     164,
#     167,
#     170,
#     186,
#     189,
#     215,
#     245,
#     285,
#     303,
#     320,
#     453,
#     487,
#     514,
#     535,
#     539,
#     549,
#     554,
#     557,
#     560,
#     621,
#     633,
#     694,
#     712,
#     739],
#    90]),
#  ('From', [[1], 3]),
#  ('Wikipedia', [[1, 963], 4]),
#  ('the',
#   [[1,
#     151,
#     191,
#     197,
#     223,
#     306,
#     316,
#     352,
#     364,
#     367,
#     375,
#     385,
#     414,
#     423,
#     435,
#     460,
#     463,
#     468,
#     484,
#     508,
#     551,
#     559,
#     577,
#     652,
#     660,
#     663,
#     669,
#     687,
#     697,
#     703,
#     722,
#     726,
#     918],
#    120]),
#  ('free', [[1], 3]),
#  ('encyclopedia', [[1], 2]),
#  ('This', [[1, 24, 260, 410, 515, 525], 9]),
#  ('article', [[1, 25, 33, 961], 7]),
#  ('includes', [[1], 1])]
